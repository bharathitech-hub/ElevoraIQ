# %% [markdown]
# # **Elevora Professional Aptitude & Compensation Intelligence Framework**
# ## A Data-Driven Solution for Salary Optimization

# %% [markdown]
# ## Project Summary
#
# The **Elevora Professional Aptitude & Compensation Intelligence Framework** is a self-initiated, end-to-end data science solution designed to assist HR teams in making objective and equitable compensation decisions. This project was independently conceptualized and developed as a proof-of-concept to address real-world challenges in salary structuring based on candidate profiles.
#
# Leveraging machine learning models and structured data, the framework predicts compensation by analyzing candidate attributes such as experience, technical proficiency, and aptitude scores. The goal is to enhance decision-making transparency, ensure pay fairness, and align hiring strategies with organizational goals through data-driven intelligence.

# %% [markdown]
# ## Real-World Business Scenario
#
# Consider a rapidly growing technology firm that is in the process of expanding its analytics team. The Human Resources department is evaluating multiple candidates for the role of Data Analyst but is facing challenges in determining fair and competitive compensation offers.
#
# Two applicants emerge as strong contenders:
# - **Candidate A**: Possesses 2 years of experience, demonstrates strong technical proficiency, and has achieved a high score on the company’s internal aptitude assessment.
# - **Candidate B**: Also has 2 years of experience but exhibits average technical capability and a comparatively lower aptitude score.
#
# Despite similar experience levels, should both candidates receive identical compensation packages?
#
# This is where the **Elevora Professional Aptitude & Compensation Intelligence Framework** proves invaluable. By inputting key attributes—such as experience, skill level, and aptitude scores—into the model, the HR team receives objective, data-driven salary recommendations.
#
# This approach empowers organizations to:
# - Ensure **equitable and merit-based compensation decisions**
# - Promote **transparency and consistency** in the hiring process
# - Align compensation packages with **industry benchmarks and role-specific expectations**
#
# By integrating such insights, companies can streamline salary structuring, reduce negotiation complexities, and enhance talent acquisition and retention strategies.

# %% [markdown]
# ### Target Users
#
# - **HR and Talent Acquisition Teams**
#   To make data-driven compensation decisions during candidate evaluation and reduce negotiation bottlenecks.
#
# - **Recruitment Analytics Professionals**
#   To gain insights into how candidate attributes correlate with compensation and optimize hiring strategies accordingly.
#
# - **HR Tech Product Teams**
#   As a foundation for integrating compensation intelligence into internal tools or platforms focused on equitable pay.
#
# - **Business Stakeholders & People Operations**
#   To ensure compensation structures align with organizational policies, talent goals, and industry benchmarks.

# %% [markdown]
# ## Business Objective and Goal
#
# This project aims to develop a data-driven compensation intelligence framework that leverages machine learning to predict fair and accurate salary estimates based on key candidate attributes such as aptitude scores, academic qualifications, and professional experience.
#
# The goal is to enable human resource and recruitment teams to make objective, transparent, and consistent salary decisions. By minimizing subjective bias and incorporating predictive analytics into the hiring process, the solution promotes equity, improves decision-making efficiency, and aligns compensation strategies with organizational standards.

# %% [markdown]
# ## **Project Workflow**
#
# The following workflow outlines the step-by-step approach used in this project:
#
# 1. **Data Collection** – Import and explore the dataset.
# 2. **Data Preprocessing** – Handle missing values, outliers, and perform feature engineering.
# 3. **Exploratory Data Analysis (EDA)** – Visualize patterns and relationships in the data.
# 4. **Feature Selection & Engineering** – Optimize features for better model performance.
# 5. **Model Development** – Train multiple regression models to predict salaries.
# 6. **Model Evaluation** – Compare performance metrics and select the best model.
# 7. **Deployment & Insights** – Present results and conclusions for business decision-making.
#
# This structured approach ensures a systematic and efficient analysis for salary optimization.

# %% [markdown]
# ### Tech Stack
#
# - **Programming Language**: Python
# - **Data Manipulation & Analysis**: Pandas, NumPy
# - **Data Visualization**: Matplotlib, Seaborn
# - **Machine Learning Models**: Linear Regression, Random Forest Regressor, XGBoost Regressor, Support Vector Regressor
# - **Model Evaluation Metrics**: R² Score, Mean Absolute Error (MAE), Root Mean Squared Error (RMSE)
# - **Feature Engineering**: Label Encoding, One-Hot Encoding, Feature Scaling
# - **Model Comparison & Visualization**: Matplotlib

# %% [markdown]
# ## Dataset Overview
#
# The dataset comprises **300 anonymized candidate profiles**, each containing multiple attributes relevant to recruitment and compensation analysis. It is structured to reflect real-world hiring scenarios in domains such as technology, healthcare, consulting, and AI/ML.
#
# ### Key Features:
# - **Candidate_ID**: Unique identifier for each candidate.
# - **Education_Level**: Highest qualification obtained (e.g., B.Sc, BCA, MCA).
# - **Years_of_Experience**: Total professional experience in years.
# - **Skills**: Technical skillsets including tools and programming languages.
# - **Certifications**: Professional certifications acquired by the candidate.
# - **Aptitude_Score**: Score from a standardized aptitude test (scale: 0–100).
# - **Industry**: Industry domain where the candidate is seeking or working.
# - **Location**: Preferred or current work location.
# - **Job_Role**: Applied or current job designation.
# - **Company_Type**: Type of company (e.g., MNC, Startup, Product-Based).
# - **Soft_Skills**: Qualitative evaluation of soft skills (e.g., Excellent, Good).
# - **Gender**: Gender identity of the candidate.
# - **Work_Gap_Status**: Indicates whether the candidate has any career break.
# - **Notice_Period**: Duration required before joining (e.g., 30 Days, Immediate).
# - **Interview_Score**: Score from the technical or HR interview (scale: 0–100).
# - **Current_Salary**: Current annual compensation (in INR).
# - **Expected_Salary**: Expected annual compensation (in INR) — this is the **target variable** for prediction.
#
# This dataset is designed to simulate real-world compensation decision-making, offering valuable insights into salary estimation and equitable hiring practices using machine learning.

# %% [markdown]
# ## **1. Data Import & Exploration**
# To begin the analysis, we import the dataset and perform an initial exploration to understand its structure.

# %%
import pandas as pd
df=pd.read_csv('/content/Elevora Professional Aptitude & Compensation Intelligence Framework.csv')
df
# Out:
#      Candidate_ID Education_Level  Years_of_Experience  \
# 0               1             BCA                    3
# 1               2            B.Sc                    6
# 2               3             MCA                   10
# 3               4            B.Sc                    2
# 4               5            B.Sc                    6
# ..            ...             ...                  ...
# 295           296             MBA                    1
# 296           297            B.Sc                    9
# 297           298             MBA                    6
# 298           299             MCA                    6
# 299           300             BCA                    9
#
#                                   Skills                 Certifications  \
# 0               Tableau; Power BI; Excel           AWS ML Certification
# 1               Tableau; Power BI; Excel           Six Sigma Green Belt
# 2          Python; SQL; Machine Learning                            NaN
# ...

# %%
df.head()
# Out:
#    Candidate_ID Education_Level  Years_of_Experience  \
# 0             1             BCA                    3
# 1             2            B.Sc                    6
# 2             3             MCA                   10
# 3             4            B.Sc                    2
# 4             5            B.Sc                    6
#
#                                 Skills        Certifications  Aptitude_Score  \
# 0             Tableau; Power BI; Excel  AWS ML Certification              83
# 1             Tableau; Power BI; Excel  Six Sigma Green Belt              60
# 2        Python; SQL; Machine Learning                   NaN              65
# 3  Deep Learning; NLP; Computer Vision  Six Sigma Green Belt              54
# 4  Deep Learning; NLP; Computer Vision  AWS ML Certification              63
#
#       Industry   Location            Job_Role   Company_Type Soft_Skills  \
# 0         BFSI       Pune         ML Engineer            MNC   Excellent
# ...

# %% [markdown]
# ## **2. Data Overview & Preprocessing**
# Before building predictive models, it is essential to check the dataset structure, identify missing values, and preprocess the data.

# %%
# Check dataset structure
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Candidate_ID         300 non-null    int64
#  1   Education_Level      300 non-null    object
#  2   Years_of_Experience  300 non-null    int64
#  3   Skills               300 non-null    object
#  4   Certifications       250 non-null    object
#  5   Aptitude_Score       300 non-null    int64
#  6   Industry             300 non-null    object
#  7   Location             300 non-null    object
#  8   Job_Role             300 non-null    object
#  9   Company_Type         300 non-null    object
#  10  Soft_Skills          300 non-null    object
#  11  Gender               300 non-null    object
#  12  Work_Gap_Status      300 non-null    object
#  13  Notice_Period        300 non-null    object
#  14  Interview_Score      300 non-null    int64
# ...

# %%
df.shape
# Out:
# (300, 17)

# %%
df.columns
# Out:
# Index(['Candidate_ID', 'Education_Level', 'Years_of_Experience', 'Skills',
#        'Certifications', 'Aptitude_Score', 'Industry', 'Location', 'Job_Role',
#        'Company_Type', 'Soft_Skills', 'Gender', 'Work_Gap_Status',
#        'Notice_Period', 'Interview_Score', 'Current_Salary',
#        'Expected_Salary'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Candidate_ID           300
# Education_Level          6
# Years_of_Experience     11
# Skills                   6
# Certifications           5
# Aptitude_Score          51
# Industry                 6
# Location                 6
# Job_Role                 5
# Company_Type             4
# Soft_Skills              3
# Gender                   3
# Work_Gap_Status          2
# Notice_Period            4
# Interview_Score         51
# Current_Salary         300
# Expected_Salary        300
# dtype: int64

# %%
# Summary statistics
df.describe()
# Out:
#        Candidate_ID  Years_of_Experience  Aptitude_Score  Interview_Score  \
# count    300.000000           300.000000      300.000000       300.000000
# mean     150.500000             5.260000       74.160000        74.360000
# std       86.746758             3.279469       14.975154        15.597264
# min        1.000000             0.000000       50.000000        50.000000
# 25%       75.750000             2.750000       61.000000        60.750000
# 50%      150.500000             5.000000       74.000000        72.000000
# 75%      225.250000             8.000000       87.000000        88.000000
# max      300.000000            10.000000      100.000000       100.000000
#
#        Current_Salary  Expected_Salary
# count    3.000000e+02     3.000000e+02
# mean     1.146666e+06     1.482865e+06
# std      4.593470e+05     6.041992e+05
# min      3.082450e+05     3.834290e+05
# 25%      7.720908e+05     9.962028e+05
# 50%      1.142244e+06     1.474152e+06
# ...

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Candidate_ID            0
# Education_Level         0
# Years_of_Experience     0
# Skills                  0
# Certifications         50
# Aptitude_Score          0
# Industry                0
# Location                0
# Job_Role                0
# Company_Type            0
# Soft_Skills             0
# Gender                  0
# Work_Gap_Status         0
# Notice_Period           0
# Interview_Score         0
# Current_Salary          0
# Expected_Salary         0
# dtype: int64

# %% [markdown]
# ## **3. Handling Missing Values**
# Missing values in the dataset can impact model performance. Before proceeding, we analyze and decide on the best method to handle them.

# %% [markdown]
# ### **3.1 Filling Missing Values Using `fillna()`**
# We apply different imputation strategies based on the data type:
# - **Numerical Columns** → Filled with median to avoid outlier impact.
# - **Categorical Columns** → Filled with mode (most frequent value).

# %%
# Fill categorical columns with mode
df.fillna(df.mode().iloc[0], inplace=True)

# %%
# Verify if missing values are handled
df.isnull().sum()
# Out:
# Candidate_ID           0
# Education_Level        0
# Years_of_Experience    0
# Skills                 0
# Certifications         0
# Aptitude_Score         0
# Industry               0
# Location               0
# Job_Role               0
# Company_Type           0
# Soft_Skills            0
# Gender                 0
# Work_Gap_Status        0
# Notice_Period          0
# Interview_Score        0
# Current_Salary         0
# Expected_Salary        0
# dtype: int64

# %% [markdown]
# #4. Data Visualization
#
# ## Importance of Data Visualization
# Data visualization plays a crucial role in understanding patterns, distributions, and relationships within the dataset.
# By utilizing various visualization techniques, we can:
# - Identify trends and outliers
# - Analyze feature distributions
# - Understand correlations and dependencies between variables
#
# ---

# %% [markdown]
# ### Visualization Overview
# - **Type:** Bar Chart
# - **Focus:** Comparison of average expected salary across various education levels
# - **Purpose:** To identify how educational attainment influences salary expectations

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.barplot(x='Expected_Salary', y='Education_Level', data=df, color='thistle')
plt.title('Expected Salary by Education Level')
plt.xlabel('Expected Salary')
plt.ylabel('Education Level')
plt.show()

# %% [markdown]
# ### Analysis & Interpretation
#
# - **Trend Identified:** Expected salary levels remain largely uniform across education tiers.
# - **Notable Exception:** MBA and MCA holders exhibit slightly elevated expectations.
# - **Inference:** Academic qualification has a modest impact on salary expectations; other factors such as skills or experience may play a stronger role.
# - **Strategic Takeaway:** Organizations can broaden their talent pool without significantly altering compensation strategies across education levels.

# %% [markdown]
# ### Visualization Overview
#
# - **Type:** Scatter Plot
# - **Focus:** Comparison of current salary trends based on years of experience across different education levels
# - **Purpose:** To analyze how professional experience and educational qualifications collectively impact current compensation

# %%
sns.scatterplot(data=df, x='Years_of_Experience', y='Current_Salary', hue='Education_Level')
plt.title('Experience vs Current Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Current Salary')
plt.show()

# %% [markdown]
# ### Analysis & Interpretation
#
# - **Trend Identified:** Current salary generally increases with years of experience, indicating a positive correlation.
# - **Notable Exception:** A few candidates with less experience are earning high salaries, possibly due to niche skills, certifications, or job roles.
# - **Inference:** While experience is a strong determinant of salary, other variables such as domain expertise and industry demand also play a significant role.
# - **Strategic Takeaway:** Organizations should consider both experience and individual skill sets when evaluating compensation, rather than relying solely on tenure.

# %% [markdown]
# ### Visualization Overview
#
# - **Type:** Regression Plot
# - **Focus:** Relationship between Aptitude Score and Interview Score
# - **Purpose:** To assess whether performance in aptitude tests is a good indicator of interview performance

# %%
sns.regplot(x='Aptitude_Score', y='Interview_Score', data=df, color='orange', line_kws={'color': 'red'})
plt.title('Aptitude Score vs Interview Score')
plt.xlabel('Aptitude Score')
plt.ylabel('Interview Score')
plt.show()

# %% [markdown]
# ### Analysis & Interpretation
#
# - **Trend Identified:** The regression line is nearly flat, indicating a weak or no correlation between aptitude and interview scores.
# - **Notable Observation:** High aptitude scores do not necessarily translate to high interview scores, and vice versa.
# - **Inference:** Aptitude performance alone may not be a reliable predictor of interview outcomes. Other factors such as communication, confidence, and personality might have greater influence.
# - **Strategic Takeaway:** Recruiters should not overly depend on aptitude tests for shortlisting candidates; a holistic evaluation approach is recommended.

# %% [markdown]
# ### Visualization Overview
#
# - **Type:** Box Plot
# - **Focus:** Comparison of Aptitude Scores based on Work Gap Status and Gender
# - **Purpose:** To analyze how career gaps and gender influence aptitude performance

# %%
sns.boxplot(data=df, x='Work_Gap_Status', y='Aptitude_Score', hue='Gender', palette='Set3')
plt.title('Work Gap vs Aptitude Score by Gender')
plt.xlabel('Work Gap Status')
plt.ylabel('Aptitude Score')
plt.show()

# %% [markdown]
# ### Analysis & Interpretation
#
# - **Trend Identified:** Aptitude scores are fairly consistent across candidates with and without work gaps, regardless of gender.
# - **Notable Observation:** Female candidates without a work gap show a slightly higher median aptitude score compared to others.
# - **Inference:** The presence or absence of a work gap does not drastically affect a candidate's aptitude score. Gender-based differences are minimal but can be explored further.
# - **Strategic Takeaway:** Work gaps should not be viewed as a negative indicator of aptitude. Hiring decisions should consider overall skillsets and not discount candidates based on career breaks.

# %% [markdown]
# ### Visualization Overview
#
# - **Type:** Heatmap
# - **Focus:** Displaying the correlation between all numerical variables
# - **Purpose:** To identify which variables are strongly related and detect potential multicollinearity or patterns in the data

# %%
numeric_df = df.select_dtypes(include='number')
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# **Analysis & Interpretation**
#
# * **Trend Identified:** A very strong positive correlation (0.97) exists between Current Salary and Expected Salary, indicating a direct and predictable relationship.
# * **Notable Exception:** All other correlations between the independent variables (Years of Experience, Aptitude Score, Interview Score) and the dependent variables (Current Salary, Expected Salary) are weak (close to zero), suggesting minimal linear association.
# * **Inference:** Linear relationships between experience and scores, and salary expectations are weak in this dataset. A candidate's current salary is the strongest linear predictor of their expected salary. Other factors not included in this analysis likely play a more significant role in determining salary.
# * **Strategic Takeaway:** When considering candidates based on Years of Experience, Aptitude Score, or Interview Score alone, organizations might not see a significant predictable difference in their salary expectations. Compensation strategies might need to focus more on current salary levels or explore other influencing factors beyond these listed variables.

# %% [markdown]
# ### 4.1. Clean Column Names
#
# To streamline preprocessing and coding readability, all column names are standardized by replacing spaces with underscores.

# %%
# Standardize column names
df.columns = df.columns.str.replace(' ', '_')

# %% [markdown]
# ### 5. Encode Ordered Categorical Features
#
# We use Label Encoding for features that have an inherent order. In this case:
# - `Soft_Skills`: Ordered as Average < Good < Excellent
# - `Notice_Period`: Ordered by urgency (Immediate < 30 Days < 60 Days)
#
# Label encoding assigns a numerical value to each category based on order.

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize label encoder
le = LabelEncoder()

# Encode ordered features
df['Soft_Skills'] = le.fit_transform(df['Soft_Skills'])
df['Notice_Period'] = le.fit_transform(df['Notice_Period'])

# %% [markdown]
# ### 5.1. Encode Unordered Categorical Features
#
# For features with no natural order, such as `Education_Level`, `Gender`, or `Job_Role`, we apply One-Hot Encoding.
# We also use `drop_first=True` to avoid the dummy variable trap.

# %%
# List of unordered categorical features
categorical_columns = [
    'Education_Level', 'Certifications', 'Industry', 'Location',
    'Job_Role', 'Company_Type', 'Gender', 'Work_Gap_Status'
]

# One-hot encode these features
df = pd.get_dummies(df, columns=categorical_columns, drop_first=True)

# %% [markdown]
# ### 6. Feature Engineering: Skills Column
#
# The `Skills` column contains multiple skills in a single string (separated by `;`). We:
# - Split and count each unique skill
# - Select only those skills that occur more than 5 times
# - Create binary columns like `has_Python`, `has_SQL` to indicate presence

# %% [markdown]
# ### 6.1 Feature Engineering
#
# To enhance model performance and ensure compatibility with machine learning algorithms, the following feature engineering strategies were applied:
#
# - **Categorical Variable Encoding**
#   All categorical features (e.g., job role, industry domain, education level) were transformed using One-Hot Encoding. This method preserves the nominal nature of the data without introducing unintended ordinal relationships.
#
# - **Numerical Feature Scaling**
#   Continuous variables were standardized using `StandardScaler` to normalize feature distributions. This was particularly important for algorithms sensitive to scale, such as Support Vector Regression.
#
# These transformations ensured a consistent data structure suitable for both linear and non-linear model architectures.

# %%
# Count individual skill frequency
skill_counts = df['Skills'].str.split('; ').explode().value_counts()

# Select skills used by at least 5 candidates
common_skills = skill_counts[skill_counts > 5].index

# Create binary columns for common skills
for skill in common_skills:
    skill_col = 'has_' + skill.replace(' ', '_')
    df[skill_col] = df['Skills'].apply(lambda x: 1 if skill in x else 0)

# Drop the original Skills column
df.drop('Skills', axis=1, inplace=True)

# %% [markdown]
# ### 6.2. Final Dataset Review
#
# After encoding and feature engineering, we review the transformed dataset to ensure it is ready for model training and analysis.

# %%
# Dataset shape and preview
print(f"Final dataset shape: {df.shape}")
df.head()
# Out:
# Final dataset shape: (300, 52)
#    Candidate_ID  Years_of_Experience  Aptitude_Score  Soft_Skills  \
# 0             1                    3              83            1
# 1             2                    6              60            1
# 2             3                   10              65            1
# 3             4                    2              54            1
# 4             5                    6              63            2
#
#    Notice_Period  Interview_Score  Current_Salary  Expected_Salary  \
# 0              1               64          807332          1039125
# 1              1               96          678881           765993
# 2              2               94         1794784          2533471
# 3              3               71         1760593          2350802
# 4              3               65         1535107          1710240
#
#    Education_Level_B.Tech  Education_Level_BCA  ...  has_NLP  \
# 0                   False                 True  ...        0
# ...

# %% [markdown]
# ### 7. Feature Scaling
#
# Feature scaling is crucial to ensure that all numeric features contribute equally to the model.
# This step becomes especially important when using distance-based algorithms (e.g., KNN, SVM).
#
# We use **StandardScaler** to standardize features by removing the mean and scaling to unit variance.

# %%
from sklearn.preprocessing import StandardScaler

# Initialize scaler
scaler = StandardScaler()

# Select only numerical columns for scaling
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns

# Apply scaling
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])

# %%
df[numerical_cols].head()
# Out:
#    Candidate_ID  Years_of_Experience  Aptitude_Score  Soft_Skills  \
# 0     -1.726287            -0.690287        0.591297    -0.025546
# 1     -1.714740             0.226023       -0.947146    -0.025546
# 2     -1.703193             1.447771       -0.612702    -0.025546
# 3     -1.691646            -0.995724       -1.348479    -0.025546
# 4     -1.680099             0.226023       -0.746480     1.251755
#
#    Notice_Period  Interview_Score  Current_Salary  Expected_Salary   has_SQL  \
# 0      -0.418884        -0.665329       -0.739966        -0.735654 -0.777353
# 1      -0.418884         1.389741       -1.020072        -1.188466 -0.777353
# 2       0.441836         1.261299        1.413312         1.741746  1.286416
# 3       1.302556        -0.215782        1.338754         1.438908 -0.777353
# 4       1.302556        -0.601108        0.847050         0.376953 -0.777353
#
#    has_Excel  ...   has_NLP  has_Deep_Learning  has_Cloud_Computing   has_AWS  \
# ...

# %% [markdown]
# ### 7.1. Train-Test Split
#
# Before model training, we split the dataset into training and testing subsets (80/20 split).
# This allows us to evaluate model performance on unseen data.

# %%
from sklearn.model_selection import train_test_split

# Define features and target
x = df.drop("Expected_Salary", axis=1) # Changed 'Salary' to 'Expected_Salary'
y = df["Expected_Salary"] # Changed 'Salary' to 'Expected_Salary'

# Train-test split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ### 8. Train Multiple Regression Models
#
# We train and evaluate four regression models:
# - Linear Regression
# - Random Forest Regressor
# - XGBoost Regressor
# - Support Vector Regressor (SVR)
#
# Each model will be evaluated using R², MAE, and RMSE.

# %% [markdown]
# ### 8.1 Model Selection Justification
#
# To ensure a balanced evaluation of both linear and non-linear relationships in the data, the following models were selected:
#
# - **Linear Regression**
#   Used as a benchmark model to establish a baseline with interpretable linear trends.
#
# - **Random Forest Regressor**
#   Chosen for its ability to capture complex, non-linear interactions and provide feature importance insights.
#
# - **XGBoost Regressor**
#   Selected for its high performance on structured data and built-in handling of overfitting through regularization.
#
# - **Support Vector Regressor (SVR)**
#   Applied to assess kernel-based learning effectiveness on compensation prediction with limited data size.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import numpy as np

# %%
# Initialize models
lr = LinearRegression()
rf = RandomForestRegressor(random_state=42)

# %%
# Fit the models to the training data
lr.fit(x_train, y_train) # Fit Linear Regression
rf.fit(x_train, y_train) # Fit Random Forest
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Predict
lr_preds = lr.predict(x_test)
rf_preds = rf.predict(x_test)

# %%
# Evaluation function
def evaluate_model(name, y_true, y_pred):
    print(f"{name} Evaluation:")
    print(f"R² Score: {r2_score(y_true, y_pred):.2f}")
    print(f"MAE: {mean_absolute_error(y_true, y_pred):.2f}")
    print(f"RMSE: {np.sqrt(mean_squared_error(y_true, y_pred)):.2f}")
    print("-" * 30)

# %%
# Evaluate both
evaluate_model("Linear Regression", y_test, lr_preds)
evaluate_model("Random Forest", y_test, rf_preds)
# Out:
# Linear Regression Evaluation:
# R² Score: 0.94
# MAE: 0.21
# RMSE: 0.27
# ------------------------------
# Random Forest Evaluation:
# R² Score: 0.93
# MAE: 0.22
# RMSE: 0.27
# ------------------------------

# %%
from xgboost import XGBRegressor

# Initialize and train
xgb = XGBRegressor(random_state=42)
xgb.fit(x_train, y_train)

# Predict
xgb_preds = xgb.predict(x_test)

# Evaluate
evaluate_model("XGBoost Regressor", y_test, xgb_preds)
# Out:
# XGBoost Regressor Evaluation:
# R² Score: 0.91
# MAE: 0.23
# RMSE: 0.31
# ------------------------------

# %%
from sklearn.svm import SVR

# Initialize and train
svr = SVR()
svr.fit(x_train, y_train)

# Predict
svr_preds = svr.predict(x_test)

# Evaluate
evaluate_model("Support Vector Regressor", y_test, svr_preds)
# Out:
# Support Vector Regressor Evaluation:
# R² Score: 0.87
# MAE: 0.30
# RMSE: 0.38
# ------------------------------

# %% [markdown]
# ##8.2 Why Classification Metrics Are Not Used
#
# This project involves predicting the expected salary of candidates based on a combination of numerical and categorical features. Since the target variable is continuous, the problem falls under the category of regression rather than classification.
#
# Metrics such as precision, recall, and F1-score are specifically designed for classification problems where the objective is to predict discrete class labels. These metrics are effective in evaluating how well a model distinguishes between different categories or outcomes.
#
# In contrast, regression tasks aim to predict continuous values. Therefore, the performance of regression models is evaluated using appropriate metrics such as:
#
# - **R² Score (Coefficient of Determination):** Indicates the proportion of variance in the dependent variable that is predictable from the independent variables.
# - **Root Mean Squared Error (RMSE):** Measures the standard deviation of prediction errors, providing insight into the average magnitude of errors.
# - **Mean Absolute Error (MAE):** Represents the average absolute difference between predicted values and actual values.
#
# Applying classification metrics to a regression problem would be conceptually incorrect and may lead to misleading interpretations. Hence, only regression-specific evaluation metrics are utilized in this project to ensure accurate and meaningful performance assessment.

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# Models and their R² scores
models = ["Linear Regression", "Random Forest", "XGBoost", "SVR"]
r2_scores = [
    r2_score(y_test, lr_preds),
    r2_score(y_test, rf_preds),
    r2_score(y_test, xgb_preds),
    r2_score(y_test, svr_preds)
]

# Bar chart
plt.bar(models, r2_scores, color='skyblue')
plt.title("Model Comparison - R² Score")
plt.ylabel("R² Score")
plt.ylim(0, 1)
plt.show()

# %%
from sklearn.metrics import mean_absolute_error

# Models and MAE values
mae_scores = [
    mean_absolute_error(y_test, lr_preds),
    mean_absolute_error(y_test, rf_preds),
    mean_absolute_error(y_test, xgb_preds),
    mean_absolute_error(y_test, svr_preds)
]

# Bar chart
plt.bar(models, mae_scores, color='lightcoral')
plt.title("Model Comparison - MAE")
plt.ylabel("Mean Absolute Error")
plt.show()

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# Models and RMSE values
rmse_scores = [
    np.sqrt(mean_squared_error(y_test, lr_preds)),
    np.sqrt(mean_squared_error(y_test, rf_preds)),
    np.sqrt(mean_squared_error(y_test, xgb_preds)),
    np.sqrt(mean_squared_error(y_test, svr_preds))
]

# Bar chart
plt.bar(models, rmse_scores, color='mediumseagreen')
plt.title("Model Comparison - RMSE")
plt.ylabel("Root Mean Squared Error")
plt.show()

# %%
import joblib

# Your trained model
model = LinearRegression()
model.fit(x_train, y_train)

# Save the model to a file
joblib.dump(model, 'model.pkl')
# Out:
# ['model.pkl']

# %% [markdown]
# ##8.3 Model Summary, Business Value, and Deployment Strategy
#
# ### Model Achievement
# The machine learning model developed in this project accurately predicts a candidate's expected salary based on multiple influential attributes, including aptitude scores, domain knowledge, experience, current compensation, skill alignment, and education level. Among the models evaluated, the Random Forest Regressor demonstrated the best performance with a high R² score and low Root Mean Squared Error (RMSE), indicating strong generalization and minimal prediction error.
#
# This validates the model’s capability to produce reliable, data-driven compensation predictions aligned with real-world expectations.
#
# ### Business Value
# - **Objective Compensation Framework**: Enables organizations to design fair and consistent salary structures, reducing subjective bias in the hiring process.
# - **Informed Hiring Decisions**: Empowers HR teams with data-backed insights into candidate worth, improving the quality of recruitment.
# - **Budget Optimization**: Assists in avoiding overcompensation or undervaluation of candidates, leading to more effective use of HR budgets.
# - **Strategic Workforce Planning**: Offers deeper understanding of talent-market dynamics and the relationship between various attributes and salary expectations.
#
# This project supports human resource functions by embedding intelligence into compensation planning, resulting in transparent, equitable, and optimized recruitment strategies.
#
# ### Deployment Strategy
# - **Model Packaging**: Export the trained model using `joblib` or `pickle` for production use.
# - **API Development**: Deploy the model via a REST API using frameworks such as Flask or FastAPI to accept candidate data and return salary predictions.
# - **User Interface**: Develop a web-based interface using tools like Streamlit or a lightweight frontend framework to allow HR users to interact with the model easily.
# - **Cloud Hosting**: Host the application on cloud platforms such as AWS, Heroku, Render, or Streamlit Cloud for seamless accessibility.
# - **Monitoring and Maintenance**: Implement monitoring tools to track model performance and data drift, and schedule periodic retraining to maintain prediction accuracy over time.
#
# The solution is scalable, customizable, and ready to be integrated into real-world HR and recruitment workflows.

# %% [markdown]
# ###9. Key Business Takeaways
#
# - **Informed Compensation Structuring**
#   The framework empowers organizations to determine fair and consistent salary benchmarks based on quantifiable attributes such as aptitude, experience, and role-specific skills.
#
# - **Improved Transparency and Equity**
#   Leveraging data-driven predictions promotes fairness in compensation practices, minimizing subjectivity and enhancing trust in HR decision-making.
#
# - **Support for Strategic Workforce Planning**
#   By aligning compensation with data insights, companies can strengthen talent acquisition and retention strategies while maintaining competitiveness in the market.

# %% [markdown]
# # New Section

# %% [markdown]
# ###10. Conclusion
#
# - Developed a predictive compensation framework to support data-driven salary decisions based on aptitude, experience, and skill attributes.
# - Applied multiple machine learning models with performance comparison to identify optimal predictors of fair compensation.
# - Ensured transparency and consistency in salary recommendations through structured preprocessing and model evaluation.
# - Demonstrated the business relevance of data science in HR analytics by aligning predictions with equitable and strategic compensation planning.
# - Positioned the framework as a scalable, real-world solution for organizations aiming to modernize and standardize their compensation structures.

# %% [markdown]
# ###10.1 Future Scope
#
# - **Production Deployment**: Transform the current prototype into a deployable application (e.g., Streamlit or Flask) that HR teams can interact with in real-time during recruitment.
# - **ATS Integration**: Integrate the framework with Applicant Tracking Systems (ATS) to automate compensation benchmarking based on candidate profiles.
# - **Geo-Salary Adjustment**: Incorporate geographical cost-of-living indices and market salary trends to provide region-specific compensation insights.
# - **Explainability Enhancements**: Embed explainable AI tools (e.g., SHAP) into the user interface to promote transparency in salary recommendations and foster trust among stakeholders.
# - **Scalability Across Roles**: Extend the model to handle predictions across diverse job roles and departments, enabling organizations to standardize pay structures enterprise-wide.

# %%
# %%writefile app.py
# Out:
# Writing app.py

# %%
# !pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 27.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 30.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 5.1 MB/s eta 0:00:00
# ...

# %%
import streamlit as st
import pandas as pd
import joblib
import datetime
import os

# %%
# Load the trained model (make sure model.pkl is in the same directory)
model = joblib.load('model.pkl')

# %%
st.title("Elevora: Professional Aptitude & Compensation Estimator")
st.markdown("Estimate expected salary based on a candidate’s aptitude and career profile.")
# Out:
# 2025-04-14 09:51:27.295 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 09:51:27.459
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2025-04-14 09:51:27.464 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 09:51:27.468 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 09:51:27.474 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# User Inputs
st.header("Candidate Profile Input")
aptitude = st.slider("Aptitude Score (0-100)", 0, 100, 50)
domain_knowledge = st.slider("Domain Knowledge (0-100)", 0, 100, 50)
experience = st.number_input("Years of Experience", min_value=0.0, max_value=50.0, value=1.0)
current_comp = st.number_input("Current Compensation (₹)", min_value=0.0, value=300000.0)
skill_alignment = st.slider("Skill Alignment (0-100)", 0, 100, 50)
education = st.selectbox("Education Level", ["Bachelors", "Masters", "PhD"])
# Out:
# 2025-04-14 09:59:15.962 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 09:59:15.972 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 09:59:15.982 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 09:59:15.984 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 09:59:15.986 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 09:59:15.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 09:59:15.991 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
# Encode education
edu_level = {"Bachelors": 0, "Masters": 1, "PhD": 2}
education_level = edu_level[education]

# %%
# Prepare data
input_df = pd.DataFrame({
    "aptitude": [aptitude],
    "domain_knowledge": [domain_knowledge],
    "experience": [experience],
    "current_compensation": [current_comp],
    "skill_alignment": [skill_alignment],
    "education_level": [education_level]
})

# %%
# Predict
if st.button("Predict Salary"):
    prediction = model.predict(input_df)[0]
    st.success(f"Predicted Expected Salary: ₹{prediction:,.2f}")
# Out:
# 2025-04-14 10:00:35.114 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 10:00:35.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 10:00:35.118 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 10:00:35.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 10:00:35.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# Optional Feature Ideas (add later)
st.markdown("---")
st.markdown("Want to improve this app?")
st.markdown("- Add PDF Export")
st.markdown("- Add Profile Comparison")
st.markdown("- Add Logging/Tracking Features")
# Out:
# 2025-04-14 10:00:52.977 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 10:00:52.986 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 10:00:52.990 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 10:00:52.994 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 10:00:52.998 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 10:00:53.003 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 10:00:53.007 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
from google.colab import files
files.download('app.py')
